# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinav-personal/Abhi-AIML-PythonTest/blob/main/Day7_8_ML_journey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
vtuple = (10,20,30)
print(type(vtuple))
print(vtuple*3)
vtuple = vtuple + (40,50)
print(vtuple)
# Out:
# <class 'tuple'>
# (10, 20, 30, 10, 20, 30, 10, 20, 30)
# (10, 20, 30, 40, 50)

# %%
vdict = {1:"Abhinav", 1:"Srivastava", "city":"Ranchi", "state":"Jharkhand"}
print(vdict[1])
# Out:
# Srivastava
