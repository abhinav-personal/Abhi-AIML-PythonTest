# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinav-personal/Abhi-AIML-PythonTest/blob/main/Day5_ML_journey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# range Function
for num in range(23,5,-2):
  print(num)
# Out:
# 23
# 21
# 19
# 17
# 15
# 13
# 11
# 9
# 7

# %%
name = "Abhinav"
counter = 0
for i in name:
  print(name[counter])
  counter = counter + 1
print("length of string: ",  counter)
# Out:
# A
# b
# h
# i
# n
# a
# v
# length of string:  7

# %%
# the word "in" in for loop is called MEMBERSHIP Operator
if "a" in "apple":
  print("true")
else:
  print("false")

#count funtion
print("bangalore".count("a",0,10))
# Out:
# true
# 2

# %%
name = ["http://yahoo.com", "http://google.com"]
for i in name:
  i = i.lstrip("hpt")
  print (i)
# Out:
# ://yahoo.com
# ://google.com

# %%
name = ["http://yahoo.com", "http://google.com","http://commomo.com"]
for i in name:
  i = i.rstrip("htp.com")
  print (i)
# Out:
# http://ya
# http://google
# http://

# %%
#print the ascii value use "ord"
print(ord("a"))
print(ord("A"))
print(ord("b"))
print(ord("B"))
# Out:
# 97
# 65
# 98
# 66

# %%
vstr = "I live in Ranchi, Ranchi is a beautiful place"
occurance = vstr.count("Ranchi")
print("Word Ranchi appread",occurance,"times.")
# Out:
# Word Ranchi appread 2 times.
