# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinav-personal/Abhi-AIML-PythonTest/blob/main/Day4_ML_journey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""Negative indexing slicing"""
name = "bangalore"
print(name[-5:2:-2])
# Out:
# a

# %%
testName = "Hello, World!"
print(testName[::2][::-1])
# Out:
# !lo olH

# %%
# Decision making statements in python
# if statement
id = 23
if id == 23:
  print("true")
else
  print("false")
