# %%
print ("THis is the first Print command on Python")
# Out:
# THis is the first Print command on Python

# %%
print("add these 2 number and the sum:", 1 + 2)
# Out:
# add these 2 number and the sum: 3
