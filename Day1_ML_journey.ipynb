# %%
print ("THis is the first Print command on Python")
# Out:
# THis is the first Print command on Python

# %%
print("add these 2 number and the sum:", 1 + 2)
# Out:
# add these 2 number and the sum: 3

# %%
a = 100
print("a: ", id(a))
b = 100
print("b:", id(b))
print (id(a) + 1)
# Out:
# a:  11657544
# b: 11657544
# 11657545

# %%
a,b,c = 10,20,"sd"
print(a,b,c)
# Out:
# 10 20 sd

# %%
# to get all the keywords in Python
import keyword as kl
print(kl.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#Multiline comment

""" This is a
Multiline comment
syntax """

print("Multiline comment")
# Out:
# Multiline comment

# %%
import types as dt
print(dt.BuiltinFunctionType)
# Out:
# <class 'builtin_function_or_method'>

# %%
# Multiline String

st = """This is the example
of storing multiline
string in Python"""

print(st)
# Out:
# This is the example
# of storing multiline
# string in Python

# %%
# Indexing

var = "this is string"
print(var[3])
# Out:
# s
