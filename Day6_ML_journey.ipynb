# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinav-personal/Abhi-AIML-PythonTest/blob/main/Day6_ML_journey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
vList = [20,3+4j,3.14,"NTT",True]
for i in vList:
    print(i,type(i))
# Out:
# 20 <class 'int'>
# (3+4j) <class 'complex'>
# 3.14 <class 'float'>
# NTT <class 'str'>
# True <class 'bool'>

# %%
#concatination of list
l1 = [10,20,"NTT", 3.4]
l2 = [34,65,4+5j, "Data"]
l3 = l1+l2
print (l3)
# Out:
# [10, 20, 'NTT', 3.4, 34, 65, (4+5j), 'Data']

# %%
#multiplication of list
l1=[10,20,30]
print(l1*2)
# Out:
# [10, 20, 30, 10, 20, 30]

# %%
#membership operator (in, notin)
l1=[10,30,45]
print(10 in l1)
print(45 not in l1)
# Out:
# True
# False

# %%
l1=[10,20,30,40]
print(l1[0])
print(l1[1])
del l1[0]
print(max(l1))
del l1
# Out:
# 10
# 20
# 40

# %%
#max function
l1 = ["Abhinav", "Srivastava", "Palak", "Anav", "Pavika"]
print(max(l1, key = len))

l2 = []
print(max(l2, key = len, default = [10,20,30]))
# Out:
# Srivastava
# [10, 20, 30]
