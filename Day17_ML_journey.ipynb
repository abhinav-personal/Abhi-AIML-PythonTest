# %% [markdown]
# <a href="https://colab.research.google.com/github/abhinav-personal/Abhi-AIML-PythonTest/blob/main/Day17_ML_journey.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Module and Packages

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
#create a folder
import os

folder_name = 'my_project'

# Create the folder if it doesn't already exist
if not os.path.exists(folder_name):
    os.makedirs(folder_name)
    print(f'Folder "{folder_name}" created successfully.')
else:
    print(f'Folder "{folder_name}" already exists.')
# Out:
# Folder "my_project" created successfully.

# %%
# %cd my_project/
# %run main.py
# Out:
# /content/my_project

# %%
import os

# Define the content for sub_package.py
sub_package_content = """
def printName(name):
    return f"Hello, {name}!"
"""

# Define the path for the new file
file_path = "sub_package.py" # Since we are already in /content/my_project/

# Write the content to the file
with open(file_path, "w") as f:
    f.write(sub_package_content)
print(f"Created {file_path} in the current directory.")

# Now run main.py again
# %run main.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /content/my_project/main.py in <module>
# ----> 1 import sub_package as sub
#       2 print(sub.printName("Abhinav"))
#
# ModuleNotFoundError: No module named 'sub_package'
